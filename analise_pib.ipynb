# %%
import pandas as pd

caminho = r'B:\cognicao\dados_brutos\Agregado-20251216034912.csv'

# Arquivo está em UTF-16LE
try:
    df = pd.read_csv(
        caminho,
        sep=';',
        encoding='utf-16le',
        thousands='.',
        decimal=',',
        low_memory=False
    )
    print("✅ Arquivo lido com sucesso!")

except Exception as e:
    print(f"❌ Erro ao ler: {e}")
    df = None

if df is not None:
    print(f"\nShape: {df.shape}")
    print(f"Colunas (primeiras 5): {list(df.columns[:5])}")
    print("\n" + "="*80)
    print("PRIMEIRAS 5 LINHAS DO DATASET")
    print("="*80 + "\n")
    df.head()
# Out:
# ✅ Arquivo lido com sucesso!
#
# Shape: (827, 229)
# Colunas (primeiras 5): ['Código do Município', 'Município', 'Estado', 'Ano de Referência', 'Código do Prestador']
#
# Primeiras linhas:
